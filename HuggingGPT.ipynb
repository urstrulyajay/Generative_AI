# %%
# !pip install -qU transformers diffusers accelerate openai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 934.9/934.9 kB 39.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.1/219.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 12.0 MB/s eta 0:00:00

# %%
import os
os.environ['OPENAI_API_KEY'] = 'YOUR_API_KEY'

# %%
from transformers.tools import OpenAiAgent
import openai

# %%
agent = OpenAiAgent(model = 'text-davinci-003',api_key = os.environ['OPENAI_API_KEY'])
# Out:
# Downloading (…)ain/tool_config.json:   0%|          | 0.00/226 [00:00<?, ?B/s]
# Downloading (…)ain/tool_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# Downloading (…)ain/tool_config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# Downloading (…)ain/tool_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]

# %%
boat_image = agent.run("generate an image of a boat in the water")
boat_image

# %%
caption = agent.run("can you caption the boat image",image = boat_image)

# %%
print (agent.run_prompt_template)

# %%
help(agent)

# %%
agent.chat()
